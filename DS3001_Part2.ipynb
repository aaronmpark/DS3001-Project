# %% [markdown]
# # Collecting Dataset

# %%
# Mount Google Drive to access the dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Create a shortcut to the Gallery and Probe Set Folders to your MyDrive (or change the path)
gallery_path = '/content/drive/MyDrive/GallerySet'
probe_path = '/content/drive/MyDrive/ProbeSet'

# %% [markdown]
# # Arcface

# %% [markdown]
# **install** insighface package for google colab & pillow-heif for handling HEIF files

# %%
# !pip install -U insightface

import torch
if torch.cuda.is_available():
  print('gpu is available')
  # !pip install onnxruntime-gpu  # to use GPU
else:
  print('gpu is not available')
  # !pip install onnxruntime
# Out:
# Requirement already satisfied: insightface in /usr/local/lib/python3.12/dist-packages (0.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from insightface) (2.0.2)
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (from insightface) (1.21.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from insightface) (4.67.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from insightface) (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from insightface) (3.10.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from insightface) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from insightface) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from insightface) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from insightface) (0.25.2)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from insightface) (1.13)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from insightface) (3.0.12)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from insightface) (2.0.8)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from insightface) (3.17.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations->insightface) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->insightface) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->insightface) (6.5.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->insightface) (2.9.0.post0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx->insightface) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx->insightface) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->insightface) (0.5.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->insightface) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->insightface) (2026.2.25)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->insightface) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->insightface) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->insightface) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->insightface) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->insightface) (1.17.0)
# gpu is available
# Requirement already satisfied: onnxruntime-gpu in /usr/local/lib/python3.12/dist-packages (1.24.4)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (5.29.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu) (1.3.0)

# %%
# !pip install pillow-heif
from pillow_heif import register_heif_opener
register_heif_opener()
# Out:
# Requirement already satisfied: pillow-heif in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: pillow>=11.1.0 in /usr/local/lib/python3.12/dist-packages (from pillow-heif) (11.3.0)

# %% [markdown]
# **prepare insightface module**

# %%
import insightface
from insightface.app import FaceAnalysis
from insightface.data import get_image as ins_get_image

app = FaceAnalysis()
app.prepare(ctx_id=0, det_thresh=0.5)
# Out:
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /root/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /root/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %% [markdown]
# **ONYX graph inspection**

# %%
import onnx
model = onnx.load('/root/.insightface/models/buffalo_l/w600k_r50.onnx')
print(onnx.helper.printable_graph(model.graph))
# Out:
# graph torch-jit-export (
#   %input.1[FLOAT, Nonex3x112x112]
# ) initializers (
#   %layer1.0.bn1.weight[FLOAT, 64]
#   %layer1.0.bn1.bias[FLOAT, 64]
#   %layer1.0.bn1.running_mean[FLOAT, 64]
#   %layer1.0.bn1.running_var[FLOAT, 64]
#   %layer1.1.bn1.weight[FLOAT, 64]
#   %layer1.1.bn1.bias[FLOAT, 64]
#   %layer1.1.bn1.running_mean[FLOAT, 64]
#   %layer1.1.bn1.running_var[FLOAT, 64]
#   %layer1.2.bn1.weight[FLOAT, 64]
#   %layer1.2.bn1.bias[FLOAT, 64]
#   %layer1.2.bn1.running_mean[FLOAT, 64]
#   %layer1.2.bn1.running_var[FLOAT, 64]
#   %layer2.0.bn1.weight[FLOAT, 64]
#   %layer2.0.bn1.bias[FLOAT, 64]
#   %layer2.0.bn1.running_mean[FLOAT, 64]
#   %layer2.0.bn1.running_var[FLOAT, 64]
#   %layer2.1.bn1.weight[FLOAT, 128]
#   %layer2.1.bn1.bias[FLOAT, 128]
#   %layer2.1.bn1.running_mean[FLOAT, 128]
#   %layer2.1.bn1.running_var[FLOAT, 128]
#   %layer2.2.bn1.weight[FLOAT, 128]
#   %layer2.2.bn1.bias[FLOAT, 128]
#   %layer2.2.bn1.running_mean[FLOAT, 128]
#   %layer2.2.bn1.running_var[FLOAT, 128]
#   %layer2.3.bn1.weight[FLOAT, 128]
#   %layer2.3.bn1.bias[FLOAT, 128]
#   %layer2.3.bn1.running_mean[FLOAT, 128]
#   %layer2.3.bn1.running_var[FLOAT, 128]
#   %layer3.0.bn1.weight[FLOAT, 128]
#   %layer3.0.bn1.bias[FLOAT, 128]
#   %layer3.0.bn1.running_mean[FLOAT, 128]
#   %layer3.0.bn1.running_var[FLOAT, 128]
#   %layer3.1.bn1.weight[FLOAT, 256]
#   %layer3.1.bn1.bias[FLOAT, 256]
#   %layer3.1.bn1.running_mean[FLOAT, 256]
#   %layer3.1.bn1.running_var[FLOAT, 256]
#   %layer3.2.bn1.weight[FLOAT, 256]
#   %layer3.2.bn1.bias[FLOAT, 256]
#   %layer3.2.bn1.running_mean[FLOAT, 256]
#   %layer3.2.bn1.running_var[FLOAT, 256]
#   %layer3.3.bn1.weight[FLOAT, 256]
#   %layer3.3.bn1.bias[FLOAT, 256]
#   %layer3.3.bn1.running_mean[FLOAT, 256]
#   %layer3.3.bn1.running_var[FLOAT, 256]
#   %layer3.4.bn1.weight[FLOAT, 256]
#   %layer3.4.bn1.bias[FLOAT, 256]
#   %layer3.4.bn1.running_mean[FLOAT, 256]
#   %layer3.4.bn1.running_var[FLOAT, 256]
#   %layer3.5.bn1.weight[FLOAT, 256]
#   %layer3.5.bn1.bias[FLOAT, 256]
#   %layer3.5.bn1.running_mean[FLOAT, 256]
#   %layer3.5.bn1.running_var[FLOAT, 256]
#   %layer3.6.bn1.weight[FLOAT, 256]
#   %layer3.6.bn1.bias[FLOAT, 256]
#   %layer3.6.bn1.running_mean[FLOAT, 256]
#   %layer3.6.bn1.running_var[FLOAT, 256]
#   %layer3.7.bn1.weight[FLOAT, 256]
#   %layer3.7.bn1.bias[FLOAT, 256]
#   %layer3.7.bn1.running_mean[FLOAT, 256]
#   %layer3.7.bn1.running_var[FLOAT, 256]
#   %layer3.8.bn1.weight[FLOAT, 256]
#   %layer3.8.bn1.bias[FLOAT, 256]
#   %layer3.8.bn1.running_mean[FLOAT, 256]
#   %layer3.8.bn1.running_var[FLOAT, 256]
#   %layer3.9.bn1.weight[FLOAT, 256]
#   %layer3.9.bn1.bias[FLOAT, 256]
#   %layer3.9.bn1.running_mean[FLOAT, 256]
#   %layer3.9.bn1.running_var[FLOAT, 256]
#   %layer3.10.bn1.weight[FLOAT, 256]
#   %layer3.10.bn1.bias[FLOAT, 256]
#   %layer3.10.bn1.running_mean[FLOAT, 256]
#   %layer3.10.bn1.running_var[FLOAT, 256]
#   %layer3.11.bn1.weight[FLOAT, 256]
#   %layer3.11.bn1.bias[FLOAT, 256]
#   %layer3.11.bn1.running_mean[FLOAT, 256]
#   %layer3.11.bn1.running_var[FLOAT, 256]
#   %layer3.12.bn1.weight[FLOAT, 256]
#   %layer3.12.bn1.bias[FLOAT, 256]
#   %layer3.12.bn1.running_mean[FLOAT, 256]
#   %layer3.12.bn1.running_var[FLOAT, 256]
#   %layer3.13.bn1.weight[FLOAT, 256]
#   %layer3.13.bn1.bias[FLOAT, 256]
#   %layer3.13.bn1.running_mean[FLOAT, 256]
#   %layer3.13.bn1.running_var[FLOAT, 256]
#   %layer4.0.bn1.weight[FLOAT, 256]
#   %layer4.0.bn1.bias[FLOAT, 256]
#   %layer4.0.bn1.running_mean[FLOAT, 256]
#   %layer4.0.bn1.running_var[FLOAT, 256]
#   %layer4.1.bn1.weight[FLOAT, 512]
#   %layer4.1.bn1.bias[FLOAT, 512]
#   %layer4.1.bn1.running_mean[FLOAT, 512]
#   %layer4.1.bn1.running_var[FLOAT, 512]
#   %layer4.2.bn1.weight[FLOAT, 512]
#   %layer4.2.bn1.bias[FLOAT, 512]
#   %layer4.2.bn1.running_mean[FLOAT, 512]
#   %layer4.2.bn1.running_var[FLOAT, 512]
#   %bn2.weight[FLOAT, 512]
#   %bn2.bias[FLOAT, 512]
#   %bn2.running_mean[FLOAT, 512]
#   %bn2.running_var[FLOAT, 512]
#   %fc.weight[FLOAT, 512x25088]
#   %fc.bias[FLOAT, 512]
#   %features.weight[FLOAT, 512]
#   %features.bias[FLOAT, 512]
#   %features.running_mean[FLOAT, 512]
#   %features.running_var[FLOAT, 512]
#   %685[FLOAT, 64x3x3x3]
#   %686[FLOAT, 64]
#   %688[FLOAT, 64x64x3x3]
#   %689[FLOAT, 64]
#   %691[FLOAT, 64x64x3x3]
#   %692[FLOAT, 64]
#   %694[FLOAT, 64x64x1x1]
#   %695[FLOAT, 64]
#   %697[FLOAT, 64x64x3x3]
#   %698[FLOAT, 64]
#   %700[FLOAT, 64x64x3x3]
#   %701[FLOAT, 64]
#   %703[FLOAT, 64x64x3x3]
#   %704[FLOAT, 64]
#   %706[FLOAT, 64x64x3x3]
#   %707[FLOAT, 64]
#   %709[FLOAT, 128x64x3x3]
#   %710[FLOAT, 128]
#   %712[FLOAT, 128x128x3x3]
#   %713[FLOAT, 128]
#   %715[FLOAT, 128x64x1x1]
#   %716[FLOAT, 128]
#   %718[FLOAT, 128x128x3x3]
#   %719[FLOAT, 128]
#   %721[FLOAT, 128x128x3x3]
#   %722[FLOAT, 128]
#   %724[FLOAT, 128x128x3x3]
#   %725[FLOAT, 128]
#   %727[FLOAT, 128x128x3x3]
#   %728[FLOAT, 128]
#   %730[FLOAT, 128x128x3x3]
#   %731[FLOAT, 128]
#   %733[FLOAT, 128x128x3x3]
#   %734[FLOAT, 128]
#   %736[FLOAT, 256x128x3x3]
#   %737[FLOAT, 256]
#   %739[FLOAT, 256x256x3x3]
#   %740[FLOAT, 256]
#   %742[FLOAT, 256x128x1x1]
#   %743[FLOAT, 256]
#   %745[FLOAT, 256x256x3x3]
#   %746[FLOAT, 256]
#   %748[FLOAT, 256x256x3x3]
#   %749[FLOAT, 256]
#   %751[FLOAT, 256x256x3x3]
#   %752[FLOAT, 256]
#   %754[FLOAT, 256x256x3x3]
#   %755[FLOAT, 256]
#   %757[FLOAT, 256x256x3x3]
#   %758[FLOAT, 256]
#   %760[FLOAT, 256x256x3x3]
#   %761[FLOAT, 256]
#   %763[FLOAT, 256x256x3x3]
#   %764[FLOAT, 256]
#   %766[FLOAT, 256x256x3x3]
#   %767[FLOAT, 256]
#   %769[FLOAT, 256x256x3x3]
#   %770[FLOAT, 256]
#   %772[FLOAT, 256x256x3x3]
#   %773[FLOAT, 256]
#   %775[FLOAT, 256x256x3x3]
#   %776[FLOAT, 256]
#   %778[FLOAT, 256x256x3x3]
#   %779[FLOAT, 256]
#   %781[FLOAT, 256x256x3x3]
#   %782[FLOAT, 256]
#   %784[FLOAT, 256x256x3x3]
#   %785[FLOAT, 256]
#   %787[FLOAT, 256x256x3x3]
#   %788[FLOAT, 256]
#   %790[FLOAT, 256x256x3x3]
#   %791[FLOAT, 256]
#   %793[FLOAT, 256x256x3x3]
#   %794[FLOAT, 256]
#   %796[FLOAT, 256x256x3x3]
#   %797[FLOAT, 256]
#   %799[FLOAT, 256x256x3x3]
#   %800[FLOAT, 256]
#   %802[FLOAT, 256x256x3x3]
#   %803[FLOAT, 256]
#   %805[FLOAT, 256x256x3x3]
#   %806[FLOAT, 256]
#   %808[FLOAT, 256x256x3x3]
#   %809[FLOAT, 256]
#   %811[FLOAT, 256x256x3x3]
#   %812[FLOAT, 256]
#   %814[FLOAT, 256x256x3x3]
#   %815[FLOAT, 256]
#   %817[FLOAT, 256x256x3x3]
#   %818[FLOAT, 256]
#   %820[FLOAT, 256x256x3x3]
#   %821[FLOAT, 256]
#   %823[FLOAT, 512x256x3x3]
#   %824[FLOAT, 512]
#   %826[FLOAT, 512x512x3x3]
#   %827[FLOAT, 512]
#   %829[FLOAT, 512x256x1x1]
#   %830[FLOAT, 512]
#   %832[FLOAT, 512x512x3x3]
#   %833[FLOAT, 512]
#   %835[FLOAT, 512x512x3x3]
#   %836[FLOAT, 512]
#   %838[FLOAT, 512x512x3x3]
#   %839[FLOAT, 512]
#   %841[FLOAT, 512x512x3x3]
#   %842[FLOAT, 512]
#   %843[FLOAT, 64x1x1]
#   %844[FLOAT, 64x1x1]
#   %845[FLOAT, 64x1x1]
#   %846[FLOAT, 64x1x1]
#   %847[FLOAT, 128x1x1]
#   %848[FLOAT, 128x1x1]
#   %849[FLOAT, 128x1x1]
#   %850[FLOAT, 128x1x1]
#   %851[FLOAT, 256x1x1]
#   %852[FLOAT, 256x1x1]
#   %853[FLOAT, 256x1x1]
#   %854[FLOAT, 256x1x1]
#   %855[FLOAT, 256x1x1]
#   %856[FLOAT, 256x1x1]
#   %857[FLOAT, 256x1x1]
#   %858[FLOAT, 256x1x1]
#   %859[FLOAT, 256x1x1]
#   %860[FLOAT, 256x1x1]
#   %861[FLOAT, 256x1x1]
#   %862[FLOAT, 256x1x1]
#   %863[FLOAT, 256x1x1]
#   %864[FLOAT, 256x1x1]
#   %865[FLOAT, 512x1x1]
#   %866[FLOAT, 512x1x1]
#   %867[FLOAT, 512x1x1]
# ) {
#   %684 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%input.1, %685, %686)
#   %479 = PRelu(%684, %843)
#   %480 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%479, %layer1.0.bn1.weight, %layer1.0.bn1.bias, %layer1.0.bn1.running_mean, %layer1.0.bn1.running_var)
#   %687 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%480, %688, %689)
#   %484 = PRelu(%687, %844)
#   %690 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%484, %691, %692)
#   %693 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [2, 2]](%479, %694, %695)
#   %489 = Add(%690, %693)
#   %490 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%489, %layer1.1.bn1.weight, %layer1.1.bn1.bias, %layer1.1.bn1.running_mean, %layer1.1.bn1.running_var)
#   %696 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%490, %697, %698)
#   %494 = PRelu(%696, %845)
#   %699 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%494, %700, %701)
#   %497 = Add(%699, %489)
#   %498 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%497, %layer1.2.bn1.weight, %layer1.2.bn1.bias, %layer1.2.bn1.running_mean, %layer1.2.bn1.running_var)
#   %702 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%498, %703, %704)
#   %502 = PRelu(%702, %846)
#   %705 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%502, %706, %707)
#   %505 = Add(%705, %497)
#   %506 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%505, %layer2.0.bn1.weight, %layer2.0.bn1.bias, %layer2.0.bn1.running_mean, %layer2.0.bn1.running_var)
#   %708 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%506, %709, %710)
#   %510 = PRelu(%708, %847)
#   %711 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%510, %712, %713)
#   %714 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [2, 2]](%505, %715, %716)
#   %515 = Add(%711, %714)
#   %516 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%515, %layer2.1.bn1.weight, %layer2.1.bn1.bias, %layer2.1.bn1.running_mean, %layer2.1.bn1.running_var)
#   %717 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%516, %718, %719)
#   %520 = PRelu(%717, %848)
#   %720 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%520, %721, %722)
#   %523 = Add(%720, %515)
#   %524 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%523, %layer2.2.bn1.weight, %layer2.2.bn1.bias, %layer2.2.bn1.running_mean, %layer2.2.bn1.running_var)
#   %723 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%524, %724, %725)
#   %528 = PRelu(%723, %849)
#   %726 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%528, %727, %728)
#   %531 = Add(%726, %523)
#   %532 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%531, %layer2.3.bn1.weight, %layer2.3.bn1.bias, %layer2.3.bn1.running_mean, %layer2.3.bn1.running_var)
#   %729 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%532, %730, %731)
#   %536 = PRelu(%729, %850)
#   %732 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%536, %733, %734)
#   %539 = Add(%732, %531)
#   %540 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%539, %layer3.0.bn1.weight, %layer3.0.bn1.bias, %layer3.0.bn1.running_mean, %layer3.0.bn1.running_var)
#   %735 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%540, %736, %737)
#   %544 = PRelu(%735, %851)
#   %738 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%544, %739, %740)
#   %741 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [2, 2]](%539, %742, %743)
#   %549 = Add(%738, %741)
#   %550 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%549, %layer3.1.bn1.weight, %layer3.1.bn1.bias, %layer3.1.bn1.running_mean, %layer3.1.bn1.running_var)
#   %744 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%550, %745, %746)
#   %554 = PRelu(%744, %852)
#   %747 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%554, %748, %749)
#   %557 = Add(%747, %549)
#   %558 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%557, %layer3.2.bn1.weight, %layer3.2.bn1.bias, %layer3.2.bn1.running_mean, %layer3.2.bn1.running_var)
#   %750 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%558, %751, %752)
#   %562 = PRelu(%750, %853)
#   %753 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%562, %754, %755)
#   %565 = Add(%753, %557)
#   %566 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%565, %layer3.3.bn1.weight, %layer3.3.bn1.bias, %layer3.3.bn1.running_mean, %layer3.3.bn1.running_var)
#   %756 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%566, %757, %758)
#   %570 = PRelu(%756, %854)
#   %759 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%570, %760, %761)
#   %573 = Add(%759, %565)
#   %574 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%573, %layer3.4.bn1.weight, %layer3.4.bn1.bias, %layer3.4.bn1.running_mean, %layer3.4.bn1.running_var)
#   %762 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%574, %763, %764)
#   %578 = PRelu(%762, %855)
#   %765 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%578, %766, %767)
#   %581 = Add(%765, %573)
#   %582 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%581, %layer3.5.bn1.weight, %layer3.5.bn1.bias, %layer3.5.bn1.running_mean, %layer3.5.bn1.running_var)
#   %768 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%582, %769, %770)
#   %586 = PRelu(%768, %856)
#   %771 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%586, %772, %773)
#   %589 = Add(%771, %581)
#   %590 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%589, %layer3.6.bn1.weight, %layer3.6.bn1.bias, %layer3.6.bn1.running_mean, %layer3.6.bn1.running_var)
#   %774 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%590, %775, %776)
#   %594 = PRelu(%774, %857)
#   %777 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%594, %778, %779)
#   %597 = Add(%777, %589)
#   %598 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%597, %layer3.7.bn1.weight, %layer3.7.bn1.bias, %layer3.7.bn1.running_mean, %layer3.7.bn1.running_var)
#   %780 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%598, %781, %782)
#   %602 = PRelu(%780, %858)
#   %783 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%602, %784, %785)
#   %605 = Add(%783, %597)
#   %606 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%605, %layer3.8.bn1.weight, %layer3.8.bn1.bias, %layer3.8.bn1.running_mean, %layer3.8.bn1.running_var)
#   %786 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%606, %787, %788)
#   %610 = PRelu(%786, %859)
#   %789 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%610, %790, %791)
#   %613 = Add(%789, %605)
#   %614 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%613, %layer3.9.bn1.weight, %layer3.9.bn1.bias, %layer3.9.bn1.running_mean, %layer3.9.bn1.running_var)
#   %792 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%614, %793, %794)
#   %618 = PRelu(%792, %860)
#   %795 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%618, %796, %797)
#   %621 = Add(%795, %613)
#   %622 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%621, %layer3.10.bn1.weight, %layer3.10.bn1.bias, %layer3.10.bn1.running_mean, %layer3.10.bn1.running_var)
#   %798 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%622, %799, %800)
#   %626 = PRelu(%798, %861)
#   %801 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%626, %802, %803)
#   %629 = Add(%801, %621)
#   %630 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%629, %layer3.11.bn1.weight, %layer3.11.bn1.bias, %layer3.11.bn1.running_mean, %layer3.11.bn1.running_var)
#   %804 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%630, %805, %806)
#   %634 = PRelu(%804, %862)
#   %807 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%634, %808, %809)
#   %637 = Add(%807, %629)
#   %638 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%637, %layer3.12.bn1.weight, %layer3.12.bn1.bias, %layer3.12.bn1.running_mean, %layer3.12.bn1.running_var)
#   %810 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%638, %811, %812)
#   %642 = PRelu(%810, %863)
#   %813 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%642, %814, %815)
#   %645 = Add(%813, %637)
#   %646 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%645, %layer3.13.bn1.weight, %layer3.13.bn1.bias, %layer3.13.bn1.running_mean, %layer3.13.bn1.running_var)
#   %816 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%646, %817, %818)
#   %650 = PRelu(%816, %864)
#   %819 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%650, %820, %821)
#   %653 = Add(%819, %645)
#   %654 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%653, %layer4.0.bn1.weight, %layer4.0.bn1.bias, %layer4.0.bn1.running_mean, %layer4.0.bn1.running_var)
#   %822 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%654, %823, %824)
#   %658 = PRelu(%822, %865)
#   %825 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%658, %826, %827)
#   %828 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [2, 2]](%653, %829, %830)
#   %663 = Add(%825, %828)
#   %664 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%663, %layer4.1.bn1.weight, %layer4.1.bn1.bias, %layer4.1.bn1.running_mean, %layer4.1.bn1.running_var)
#   %831 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%664, %832, %833)
#   %668 = PRelu(%831, %866)
#   %834 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%668, %835, %836)
#   %671 = Add(%834, %663)
#   %672 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%671, %layer4.2.bn1.weight, %layer4.2.bn1.bias, %layer4.2.bn1.running_mean, %layer4.2.bn1.running_var)
#   %837 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%672, %838, %839)
#   %676 = PRelu(%837, %867)
#   %840 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%676, %841, %842)
#   %679 = Add(%840, %671)
#   %680 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%679, %bn2.weight, %bn2.bias, %bn2.running_mean, %bn2.running_var)
#   %681 = Flatten[axis = 1](%680)
#   %682 = Gemm[alpha = 1, beta = 1, transB = 1](%681, %fc.weight, %fc.bias)
#   %683 = BatchNormalization[epsilon = 9.99999974737875e-06, momentum = 0.899999976158142](%682, %features.weight, %features.bias, %features.running_mean, %features.running_var)
#   return %683
# }
# /tmp/ipykernel_31922/3736105999.py:3: DeprecationWarning: Deprecated since 1.19. Consider using onnx.printer.to_text() instead.
#   print(onnx.helper.printable_graph(model.graph))

# %% [markdown]
# **feature extraction**

# %%
import os
import cv2
import numpy as np
from pillow_heif import register_heif_opener
from PIL import Image
register_heif_opener()

gallery_path = '/content/drive/MyDrive/GallerySet'
probe_path = '/content/drive/MyDrive/ProbeSet'

def extract_arcface_features(dataset_path):
  features = []
  labels = []
  filenames = []

  for person in sorted(os.listdir(dataset_path)):
    person_path = os.path.join(dataset_path, person)
    if not os.path.isdir(person_path):
      continue
    for file in sorted(os.listdir(person_path)):
      if not file.lower().endswith(('.jpg', '.jpeg', '.png', '.heic')):
        continue
      filepath = os.path.join(person_path, file)
      try:
        # Handle HEIC and regular images
        pil_img = Image.open(filepath).convert('RGB')
        img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
        faces = app.get(img)
        if len(faces) == 0:
          print(f"  No face detected: {person}/{file}")
          continue
        if len(faces) > 1:
          print(f"  Warning: {len(faces)} faces detected in {person}/{file}, using largest")
        features.append(faces[0].normed_embedding)
        labels.append(person)
        filenames.append(file)
        print(f"  processed: {person}/{file}")
      except Exception as e:
        print(f"  Error on {person}/{file}: {e}")
  return np.array(features), labels, filenames

print("Extracting gallery features...")
gallery_features, gallery_labels, gallery_files = extract_arcface_features(gallery_path)
print(f"\nGallery: {len(gallery_features)} features extracted")

print("\nExtracting probe features...")
probe_features, probe_labels, probe_files = extract_arcface_features(probe_path)
print(f"\nProbe: {len(probe_features)} features extracted")
# Out:
# Extracting gallery features...
#   processed: Aaron Park/IMG_0112.HEIC
#   processed: Aaron Park/IMG_0272.jpg
#   processed: Aaron Park/IMG_1453.HEIC
#   processed: Aaron Park/IMG_2642.HEIC
#   processed: Aaron Park/IMG_3938.HEIC
#   processed: Aaron Park/IMG_4279.HEIC
#   processed: Aaron Park/IMG_4512.HEIC
#   processed: Aaron Park/IMG_4592.HEIC
#   processed: Aaron Park/IMG_8261.HEIC
#   Warning: 2 faces detected in Aaron Park/IMG_9433.HEIC, using largest
#   processed: Aaron Park/IMG_9433.HEIC
#   Warning: 5 faces detected in Zion Williamson/light edit (5).jpg, using largest
#   processed: Zion Williamson/light edit (5).jpg
#   Warning: 5 faces detected in Zion Williamson/light edit (6).jpg, using largest
#   processed: Zion Williamson/light edit (6).jpg
#   processed: Zion Williamson/medium blur (1).jpg
#   processed: Zion Williamson/medium blur (2).jpg
#   processed: Zion Williamson/medium blur (3).jpg
#   processed: Zion Williamson/medium blur (4).jpg
#   processed: Zion Williamson/medium blur (5).jpg
#   processed: Zion Williamson/medium blur (6).jpg
#   Warning: 5 faces detected in Zion Williamson/medium edit (1).jpg, using largest
#   processed: Zion Williamson/medium edit (1).jpg
#   Warning: 5 faces detected in Zion Williamson/medium edit (2).jpg, using largest
#   processed: Zion Williamson/medium edit (2).jpg
#   Warning: 5 faces detected in Zion Williamson/medium edit (3).jpg, using largest
#   processed: Zion Williamson/medium edit (3).jpg
#   Warning: 5 faces detected in Zion Williamson/medium edit (4).jpg, using largest
#   processed: Zion Williamson/medium edit (4).jpg
#   Warning: 4 faces detected in Zion Williamson/medium edit (5).jpg, using largest
#   processed: Zion Williamson/medium edit (5).jpg
#   Warning: 4 faces detected in Zion Williamson/medium edit (6).jpg, using largest
#   processed: Zion Williamson/medium edit (6).jpg
#   processed: Zion Williamson/slight blur (1).jpg
#   processed: Zion Williamson/slight blur (2).jpg
#   processed: Zion Williamson/slight blur (3).jpg
#   processed: Zion Williamson/slight blur (4).jpg
#   processed: Zion Williamson/slight blur (5).jpg
#   processed: Zion Williamson/slight blur (6).jpg
#   processed: Zion Williamson/slight bright (1).jpg
#   processed: Zion Williamson/slight bright (2).jpg
#   processed: Zion Williamson/slight bright (3).jpg
#   processed: Zion Williamson/slight bright (4).jpg
#   processed: Zion Williamson/slight bright (5).jpg
#   processed: Zion Williamson/slight bright (6).jpg
#   processed: Zion Williamson/very blur (1).jpg
#   processed: Zion Williamson/very blur (2).jpg
#   processed: Zion Williamson/very blur (3).jpg
#   processed: Zion Williamson/very blur (4).jpg
#   processed: Zion Williamson/very blur (5).jpg
#   processed: Zion Williamson/very blur (6).jpg
#   processed: Zion Williamson/very bright (1).jpg
#   processed: Zion Williamson/very bright (2).jpg
#   processed: Zion Williamson/very bright (3).jpg
#   processed: Zion Williamson/very bright (4).jpg
#   processed: Zion Williamson/very bright (5).jpg
#   processed: Zion Williamson/very bright (6).jpg
#
# Probe: 581 features extracted

# %% [markdown]
# # VGG

# %% [markdown]
# **install and prepare module**

# %%
import torch
import torchvision.models as models
import torchvision.transforms as transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

vgg = models.vgg19(weights='DEFAULT')

feature_extractor = torch.nn.Sequential(
    vgg.features,
    vgg.avgpool,
    torch.nn.Flatten(),
    vgg.classifier[0],  # Linear 25088 --> 4096
    vgg.classifier[1],  # ReLU
).to(device)
feature_extractor.eval()
# Out:
# Using device: cuda
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (1): AdaptiveAvgPool2d(output_size=(7, 7))
#   (2): Flatten(start_dim=1, end_dim=-1)
#   (3): Linear(in_features=25088, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
# )

# %%
import os
import numpy as np
from PIL import Image

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

def extract_vgg_features(dataset_path):
  features = []
  labels = []
  filenames = []

  for person in sorted(os.listdir(dataset_path)):
    person_path = os.path.join(dataset_path, person)
    if not os.path.isdir(person_path):
      continue
    for file in sorted(os.listdir(person_path)):
      if not file.lower().endswith(('.jpg', '.jpeg', '.png', '.heic')):
        continue
      filepath = os.path.join(person_path, file)
      try:
        img = Image.open(filepath).convert('RGB')
        tensor = transform(img).unsqueeze(0).to(device)  # send to GPU
        with torch.no_grad():
          feat = feature_extractor(tensor)
        features.append(feat.squeeze().cpu().numpy())  # back to CPU
        labels.append(person)
        filenames.append(file)
        print(f"  processed: {person}/{file}")
      except Exception as e:
        print(f"  Error on {person}/{file}: {e}")

  return np.array(features), labels, filenames

print("Extracting VGG gallery features...")
vgg_gallery_features, vgg_gallery_labels, vgg_gallery_files = extract_vgg_features(gallery_path)
print(f"\nGallery: {len(vgg_gallery_features)} features extracted")

print("\nExtracting VGG probe features...")
vgg_probe_features, vgg_probe_labels, vgg_probe_files = extract_vgg_features(probe_path)
print(f"\nProbe: {len(vgg_probe_features)} features extracted")
# Out:
# Extracting VGG gallery features...
#   processed: Aaron Park/IMG_0112.HEIC
#   processed: Aaron Park/IMG_0272.jpg
#   processed: Aaron Park/IMG_1453.HEIC
#   processed: Aaron Park/IMG_2642.HEIC
#   processed: Aaron Park/IMG_3938.HEIC
#   processed: Aaron Park/IMG_4279.HEIC
#   processed: Aaron Park/IMG_4512.HEIC
#   processed: Aaron Park/IMG_4592.HEIC
#   processed: Aaron Park/IMG_8261.HEIC
#   processed: Aaron Park/IMG_9433.HEIC
#   processed: Aaron Park/IMG_9576.HEIC
#   processed: Aaron Park/IMG_9905.HEIC
#   processed: Angelia/DSCN2263.JPG
#   processed: Angelia/DSCN2286.JPG
#   processed: Angelia/IMG_0375.heic
#   processed: Angelia/IMG_0423.HEIC
#   processed: Angelia/IMG_0734.HEIC
#   processed: Angelia/IMG_1763.HEIC
#   processed: Angelia/IMG_1785.HEIC
#   processed: Angelia/IMG_2041.HEIC
#   processed: Angelia/IMG_2468.HEIC
#   processed: Angelia/IMG_2539.HEIC
#   processed: Angelia/IMG_9406.HEIC
#   processed: Angelia/IMG_9751.HEIC
#   processed: Elyse Undan/IMG_5983.heic
#   processed: Elyse Undan/IMG_5984.heic
#   processed: Elyse Undan/IMG_5985.jpg
#   processed: Elyse Undan/IMG_5987.jpg
#   processed: Elyse Undan/IMG_5988.jpg
#   processed: Elyse Undan/IMG_5990.jpg
#   processed: Elyse Undan/IMG_5991.jpg
#   processed: Elyse Undan/IMG_5994.jpg
#   processed: Elyse Undan/IMG_5995.jpg
#   processed: Elyse Undan/IMG_5996.jpg
#   processed: Elyse Undan/IMG_6041.HEIC
#   processed: Elyse Undan/IMG_6045.HEIC
#   processed: Gabe Vincent/1526959527508-18_05_21-Gabe-Vincent-2104233-5.576x324.jpg
#   processed: Gabe Vincent/65492-1-5d780c28502422p.jpg
#   processed: Gabe Vincent/7c747bf4-fb71-4c64-83e0-08f00da158e1_1920x1080.jpg
#   processed: Zion Williamson/heavy edit (1).jpg
#   processed: Zion Williamson/heavy edit (2).jpg
#   processed: Zion Williamson/heavy edit (3).jpg
#   processed: Zion Williamson/heavy edit (4).jpg
#   processed: Zion Williamson/heavy edit (5).jpg
#   processed: Zion Williamson/heavy edit (6).jpg
#   processed: Zion Williamson/light edit (1).jpg
#   processed: Zion Williamson/light edit (2).jpg
#   processed: Zion Williamson/light edit (3).jpg
#   processed: Zion Williamson/light edit (4).jpg
#   processed: Zion Williamson/light edit (5).jpg
#   processed: Zion Williamson/light edit (6).jpg
#   processed: Zion Williamson/medium blur (1).jpg
#   processed: Zion Williamson/medium blur (2).jpg
#   processed: Zion Williamson/medium blur (3).jpg
#   processed: Zion Williamson/medium blur (4).jpg
#   processed: Zion Williamson/medium blur (5).jpg
#   processed: Zion Williamson/medium blur (6).jpg
#   processed: Zion Williamson/medium edit (1).jpg
#   processed: Zion Williamson/medium edit (2).jpg
#   processed: Zion Williamson/medium edit (3).jpg
#   processed: Zion Williamson/medium edit (4).jpg
#   processed: Zion Williamson/medium edit (5).jpg
#   processed: Zion Williamson/medium edit (6).jpg
#   processed: Zion Williamson/slight blur (1).jpg
#   processed: Zion Williamson/slight blur (2).jpg
#   processed: Zion Williamson/slight blur (3).jpg
#   processed: Zion Williamson/slight blur (4).jpg
#   processed: Zion Williamson/slight blur (5).jpg
#   processed: Zion Williamson/slight blur (6).jpg
#   processed: Zion Williamson/slight bright (1).jpg
#   processed: Zion Williamson/slight bright (2).jpg
#   processed: Zion Williamson/slight bright (3).jpg
#   processed: Zion Williamson/slight bright (4).jpg
#   processed: Zion Williamson/slight bright (5).jpg
#   processed: Zion Williamson/slight bright (6).jpg
#   processed: Zion Williamson/very blur (1).jpg
#   processed: Zion Williamson/very blur (2).jpg
#   processed: Zion Williamson/very blur (3).jpg
#   processed: Zion Williamson/very blur (4).jpg
#   processed: Zion Williamson/very blur (5).jpg
#   processed: Zion Williamson/very blur (6).jpg
#   processed: Zion Williamson/very bright (1).jpg
#   processed: Zion Williamson/very bright (2).jpg
#   processed: Zion Williamson/very bright (3).jpg
#   processed: Zion Williamson/very bright (4).jpg
#   processed: Zion Williamson/very bright (5).jpg
#   processed: Zion Williamson/very bright (6).jpg
#
# Probe: 588 features extracted

# %% [markdown]
# # Downloading Extracted Files

# %%
import numpy as np

save_path = '/content/drive/MyDrive/'

# Save Arcface features
np.save(save_path + 'arcface_gallery_features.npy', gallery_features)
np.save(save_path + 'arcface_probe_features.npy', probe_features)
np.save(save_path + 'arcface_gallery_labels.npy', np.array(gallery_labels))
np.save(save_path + 'arcface_probe_labels.npy', np.array(probe_labels))

print("All Arcface features saved to Drive!")
print(f"Arcface gallery: {gallery_features.shape}")
print(f"Arcface probe: {probe_features.shape}")

# Save VGG features
np.save(save_path + 'vgg_gallery_features.npy', vgg_gallery_features)
np.save(save_path + 'vgg_probe_features.npy', vgg_probe_features)
np.save(save_path + 'vgg_gallery_labels.npy', np.array(vgg_gallery_labels))
np.save(save_path + 'vgg_probe_labels.npy', np.array(vgg_probe_labels))

print("All VGG features saved to Drive!")
print(f"VGG gallery: {vgg_gallery_features.shape}")
print(f"VGG probe: {vgg_probe_features.shape}")
# Out:
# All Arcface features saved to Drive!
# Arcface gallery: (133, 512)
# Arcface probe: (581, 512)
# All VGG features saved to Drive!
# VGG gallery: (134, 4096)
# VGG probe: (588, 4096)

# %% [markdown]
# # Arcface Example Code with Example Dataset

# %% [markdown]
# **install** insighface package for google colab

# %%
# !pip install -U insightface

# import torch
# if torch.cuda.is_available():
#   print('gpu is available')
#   !pip install onnxruntime-gpu  # to use GPU
# else:
#   print('gpu is not available')
#   !pip install onnxruntime

# %% [markdown]
# **download sample dataset**

# %%
# !mkdir datasets
# !wget https://github.com/hamidsadeghi68/face-clustering/raw/main/sample_images/sample_lfw_images.zip -P datasets
# !unzip "./datasets/sample_lfw_images.zip" -d './datasets/sample_lfw_images'

# %% [markdown]
# **prepare insightface module**

# %%
# import insightface
# from insightface.app import FaceAnalysis
# from insightface.data import get_image as ins_get_image

# app = FaceAnalysis()
# app.prepare(ctx_id=0, det_thresh=0.5)

# %%
# import onnx
# model = onnx.load('/root/.insightface/models/buffalo_l/w600k_r50.onnx')
# print(onnx.helper.printable_graph(model.graph))

# %% [markdown]
# **feature extraction**

# %%
# import os
# import cv2
# import numpy as np

# dataset_path = './datasets/sample_lfw_images'
# files = os.listdir(dataset_path)

# accepted_files = []
# features = []
# counter = 1
# for file in files:
#   if not file.endswith('.jpg'):
#     continue
#   print('prosessing image %d: %s'%(counter,file))

#   img = cv2.imread(os.path.join(dataset_path, file))
#   faces = app.get(img)
#   features.append(faces[0].normed_embedding)

#   accepted_files.append(file)

#   counter+=1

# %%
# print(f"Embedding shape: {features[0].shape}")
# print(f"Total images processed: {len(features)}")

# %% [markdown]
# # VGG Example Code with Example Dataset

# %% [markdown]
# **install and prepare module**

# %%
# import torch
# import torchvision.models as models
# import torchvision.transforms as transforms

# vgg = models.vgg19(weights='DEFAULT')

# feature_extractor = torch.nn.Sequential(
#     vgg.features,
#     vgg.avgpool,
#     torch.nn.Flatten(),
#     vgg.classifier[0],
#     vgg.classifier[1],
# )
# feature_extractor.eval()
# print(vgg)

# %% [markdown]
# **feature extraction**

# %%
# from PIL import Image
# import numpy as np

# transform = transforms.Compose([
#     transforms.Resize((224, 224)),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406],
#                          std=[0.229, 0.224, 0.225])
# ])

# dataset_path = './datasets/sample_lfw_images'
# files = sorted([f for f in os.listdir(dataset_path) if f.endswith('.jpg')])

# vgg_features = []
# counter = 1
# with torch.no_grad():
#     for file in files:
#         print(f"processing image {counter}: {file}")
#         img = Image.open(os.path.join(dataset_path, file)).convert('RGB')
#         tensor = transform(img).unsqueeze(0)
#         feat = feature_extractor(tensor)
#         vgg_features.append(feat.squeeze().numpy())
#         counter += 1

# print(f"\nVGG feature shape: {vgg_features[0].shape}")
# print(f"Total images processed: {len(vgg_features)}")
